# %%
import pandas as pd 

traindata = pd.read_csv('/content/drive/MyDrive/Dataset/alltrain.csv')
testdata = pd.read_csv('/content/drive/MyDrive/Dataset/alltest.csv')
print(traindata[0:5])
print(testdata[0:5])
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,1,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Label         Time   ID   Signal1   Signal2  Signal3  Signal4
# 0      0  2088.413387  id5  0.000000  0.958686      NaN      NaN
# 1      0  2089.554106  id8  0.246839       NaN      NaN      NaN
# 2      0  2090.885618  id3  0.200000  1.000000      NaN      NaN
# 3      0  2091.658406  id7  0.063888  0.000000      NaN      NaN
# 4      0  2100.364459  id9  0.449511       NaN      NaN      NaN
#   Label           Time    ID Signal1_of_ID Signal2_of_ID Signal3_of_ID  \
# 0     0  63006572.0314   id1      0.336597          0.75           NaN
# 1     0  63006573.8338   id6           1.0      0.777778           NaN
# 2     0  63006575.4139  id10      0.345212      0.888889      0.999196
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
